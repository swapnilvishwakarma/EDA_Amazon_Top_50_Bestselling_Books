# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnilvishwakarma/EDA_Amazon_Top_50_Bestselling_Books/blob/main/EDA_Amazon_Top_50_Bestselling_Books.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Amazon Top 50 Bestselling Books 2009 - 2019**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.dpi'] = 300
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("bestsellers with categories.csv")
df.head()
# Out:
#                                                 Name  ...        Genre
# 0                      10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                  11/22/63: A Novel  ...      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                             1984 (Signet Classics)  ...      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
#
# [5 rows x 7 columns]

# %%
df.tail()
# Out:
#                                                   Name  ...        Genre
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 547  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 548  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 549  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
#
# [5 rows x 7 columns]

# %%
df.shape
# Out:
# (550, 7)

# %% [markdown]
# It has 550 row and 7 cols!

# %%
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %% [markdown]
# There is no null value.

# %%
df['Genre'].unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %% [markdown]
# There are only genres: Non Fiction and Fiction

# %%
plt.hist(df['Reviews'])
# Out:
# (array([287., 131.,  87.,  25.,   4.,   8.,   5.,   0.,   0.,   3.]),
#  array([3.70000e+01, 8.81740e+03, 1.75978e+04, 2.63782e+04, 3.51586e+04,
#         4.39390e+04, 5.27194e+04, 6.14998e+04, 7.02802e+04, 7.90606e+04,
#         8.78410e+04]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Most of the books have <= 20,000 reviews!

# %%
plt.hist(df['User Rating'])
# Out:
# (array([  1.,   1.,   0.,   5.,  14.,  14.,  63.,  60., 213., 179.]),
#  array([3.3 , 3.46, 3.62, 3.78, 3.94, 4.1 , 4.26, 4.42, 4.58, 4.74, 4.9 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Most of the books are rated >= 4.2 :)

# %%
fig = px.histogram(df, x="User Rating",labels={'':'The Number of Books'}, title="User Rating Histogram", cumulative=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="39f7c6be-03ab-4f83-833b-d11bee543136" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("39f7c6be-03ab-4f83-833b-d11bee543136")) {
#                     Plotly.newPlot(
#                         '39f7c6be-03ab-4f83-833b-d11bee543136',
# ...

# %% [markdown]
# Almost half of the users have rated more than 4.5 stars

# %%
df['Genre'].value_counts()
# Out:
# Non Fiction    310
# Fiction        240
# Name: Genre, dtype: int64

# %% [markdown]
# Can be considered as a balanced dataset

# %%
sns.set_style("whitegrid");
sns.pairplot(df, hue="Genre", size=3);
plt.show()

# %% [markdown]
# There is no clear separation between both the classes (overlapping a lot)
